# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitragopalappa/model/blob/master/DML_COVID_decision_making.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INSTRUCTIONS: How to upload .ipynb file to your Google email account
# #### 1. Open Google Colab on web browser, login with your google mail account.
# #### 2. Click file "File--> Upload notebook" and upload the DML-COVID-decision-making.ipynb file
#
# # INSTRUCTIONS: HOW TO USE
# #### 1. CLICK "File--> save a copy to drive" (This will create a copy in your google drive)
# #### 2. Click 'Runtime-->Run all'

# %%
import matplotlib.pyplot as plt
from IPython.display import Image
# !pip install progress
# !git clone https://github.com/diseasemodeling/COVID19
# Out:
# ...
#   Created wheel for progress: filename=progress-1.5-cp36-none-any.whl size=8074 sha256=bb42cfae13be50505aa302dfdddeba1396c86078a870eb7f99f0c9eefba3731a
#   Stored in directory: /root/.cache/pip/wheels/6c/c8/80/32a294e3041f006c661838c05a411c7b7ffc60ff939d14e116
# Successfully built progress
# ...
# Cloning into 'COVID19'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 95 (delta 36), reused 60 (delta 24), pack-reused 0
# Unpacking objects: 100% (95/95), done.

# %%
# !pwd # print current working directory
# %cd COVID19
# Out:
# /content
# /content/COVID19

# %% [markdown]
# # 3.  Follow instructions given by model in below section, it would ask you to
# #### a). Enter U.S. State; b). Enter a decision choice for social distancing, contact tracing and testing capacity, and universal testing capacity over a 52 week period; c). Option to write data to Excel

# %%
# !python COVID_model_colab.py
# Out:
# Code In Progess:
#
# Code In Progess: 	 |████████████████████████████████| 427/427
# Finished the run

# %% [markdown]
# # 4. View: This section displays the decision choice you entered

# %%
Image('7.png')

# %% [markdown]
# # 5. View OUTPUT: This section  displays the simulation results
#
# # 6. To evaluate a different decision just repeat from Step 1 (saving a copy will ensure figures from your previous scenario do not get overwritten)

# %%
Image('1.png')

# %%
Image('2.png')

# %%
Image('3.png')

# %%
Image('4.png')

# %%
Image('5.png')

# %%
Image('6.png')
